# %%
import pandas

# %%
import pandas as pd
import os

# Define paths to the data files
data_dir = 'data'
physician_list_path = os.path.join(data_dir, 'Physicianlist.xlsx')
doctor_image_details_path = os.path.join(data_dir, 'doctor_image_details (1).csv')

# %%
# Load the Physician list (Excel)
# Note: This file is ~15MB, so it may take a few seconds to load
df_physicians = pd.read_excel(physician_list_path)
print(f"Loaded Physician list: {df_physicians.shape}")

# Load the Doctor image details (CSV)
df_images = pd.read_csv(doctor_image_details_path)
print(f"Loaded Doctor image details: {df_images.shape}")

# %%
# Load the Physician list (Excel)
# Note: This file is ~15MB, so it may take a few seconds to load
df_phy = pd.read_excel("data/R232C6_Dhanmondi_Data (2).xlsx")
print(f"Loaded Physician list: {df_physicians.shape}")
df_phy
# Out:
# Loaded Physician list: (66109, 49)
#                PRSID  MONTH  ROUND  YEAR  BOOKID   SHOPID      CDATE  \
# 0     PRS232C6001763    232    232  2026  DHK648  DHK1439 2026-04-11
# 1     PRS232C6001763    232    232  2026  DHK648  DHK1439 2026-04-11
# 2     PRS232C6001763    232    232  2026  DHK648  DHK1439 2026-04-11
# 3     PRS232C6001769    232    232  2026  DHK648  DHK1439 2026-04-11
# 4     PRS232C6001769    232    232  2026  DHK648  DHK1439 2026-04-11
# ...              ...    ...    ...   ...     ...      ...        ...
# 9635  PRS232C6045337    232    232  2026  DHK655  DHK2251 2026-04-14
# 9636  PRS232C6045337    232    232  2026  DHK655  DHK2251 2026-04-14
# 9637  PRS232C6046123    232    232  2026  DHK642  DHK1590 2026-04-11
# 9638  PRS232C6046123    232    232  2026  DHK642  DHK1590 2026-04-11
# 9639  PRS232C6046123    232    232  2026  DHK642  DHK1590 2026-04-11
#
#           PDATE  PRSTYPE  PSCSLNO  ... CINSTCD      EDATE     ETIME  \
# ...

# %%
df_image = pd.read_csv("data/doctor_image_details (1).csv")
print(f"Loaded Physician list: {df_image.shape}")
df_image
# Out:
# Loaded Physician list: (1839, 2)
#                                    IMAGE_NAME_WITH_PATH  \
# 0     /content/drive/MyDrive/All_Image/PR232C6DHK23_...
# 1     /content/drive/MyDrive/All_Image/PR232C6DHK23_...
# 2     /content/drive/MyDrive/All_Image/PR232C6DHK23_...
# 3     /content/drive/MyDrive/All_Image/PR232C6DHK23_...
# 4     /content/drive/MyDrive/All_Image/PR232C6DHK23_...
# ...                                                 ...
# 1834  /content/drive/MyDrive/All_Image/PR232C6DHKZC_...
# 1835  /content/drive/MyDrive/All_Image/PR232C6DHKZC_...
# 1836  /content/drive/MyDrive/All_Image/PR232C6DHKZC_...
# 1837  /content/drive/MyDrive/All_Image/PR232C6DHKZC_...
# 1838  /content/drive/MyDrive/All_Image/PR232C6DHKZC_...
#
#                                 DOCTOR_DETAILS_COMBINED
# 0        DR S M SIDDIQUR RAHMAN, MBBS, D-CARD, MD, FACC
# 1                          DR MD. NUR HOSSAIN, MBBS, MD
# 2     DR MD FAIZUL ISLAM CHOWDHURY, MBBS, FCPS, PHD,...
# ...

# %%
df_image = pd.read_csv("data/mapped_doctor_data.csv")
print(f"Loaded Physician list: {df_image.shape}")
df_image.head()
# Out:
# Loaded Physician list: (9640, 40)
#                                 IMAGE_NAME_WITH_PATH  \
# 0  /content/drive/MyDrive/All_Image/PR232C6DHK23_...
# 1  /content/drive/MyDrive/All_Image/PR232C6DHK23_...
# 2  /content/drive/MyDrive/All_Image/PR232C6DHK23_...
# 3  /content/drive/MyDrive/All_Image/PR232C6DHK23_...
# 4  /content/drive/MyDrive/All_Image/PR232C6DHK23_...
#
#                           DOCTOR_DETAILS_COMBINED           PRSID  MONTH  \
# 0  DR S M SIDDIQUR RAHMAN, MBBS, D-CARD, MD, FACC  PRS232C6016929    232
# 1  DR S M SIDDIQUR RAHMAN, MBBS, D-CARD, MD, FACC  PRS232C6016929    232
# 2  DR S M SIDDIQUR RAHMAN, MBBS, D-CARD, MD, FACC  PRS232C6016929    232
# 3  DR S M SIDDIQUR RAHMAN, MBBS, D-CARD, MD, FACC  PRS232C6016929    232
# 4  DR S M SIDDIQUR RAHMAN, MBBS, D-CARD, MD, FACC  PRS232C6016929    232
#
#    ROUND  YEAR  BOOKID   SHOPID       CDATE       PDATE  ...  CINSTCD  \
# 0    232  2026  DHK623  DHK0826  2026-04-12  2026-04-09  ...    H1538
# ...
